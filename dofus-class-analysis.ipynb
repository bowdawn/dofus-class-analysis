# %%
from selenium import webdriver
import httpx
from bs4 import BeautifulSoup
import json
import copy

# %%
def get_html(url, element_selector):
    # Initialize the webdriver using WebDriverManager
    driver = webdriver.Chrome()
    driver.get(url)
    
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    # Find the element based on the provided selector
    selected_element = soup.select_one(element_selector)
    return selected_element

    
def extract_links_from_html(html_content):
    # Find all anchor tags (a) and extract their href attributes
    links = [a.get('href') for a in html_content.find_all('a')]

    # Filter out None values and remove duplicates
    unique_links = list(filter(None, set(links)))
    return unique_links


def extract_spell_info(html_content):
    spell_name_element = html_content.find('h2', class_='ak-spell-name')
    # Create a copy of the h2 element
    copy_spell_name_element = BeautifulSoup(str(spell_name_element), 'html.parser')
    # Remove undesired tags from the copy
    for tag in copy_spell_name_element.find_all(['div', 'span']):
        tag.decompose()
    # Extract spell name directly from the copied element
    spell_name = copy_spell_name_element.text.strip()
    # Extract range and AP content
    range_ap_content = html_content.find('span', class_='ak-spell-po-pa')
    # Create a copy of the h2 element
    copy_range_ap_element = BeautifulSoup(str(range_ap_content), 'html.parser')
    # Extract Minimum Required Level
    level =  html_content.select_one('.ak-spell-details-level .ak-selected')
    spell_description_content = html_content.find('span', class_='ak-spell-description')
    spell_details_effect_content = html_content.find('div', class_='ak-spell-details-effects')
    ak_main_content_elements = spell_details_effect_content.select('.ak-main-content')
    text = ""
    aside = ""
    effects = []
    for element in ak_main_content_elements:
        title = element.select_one('.ak-title').text.strip()
        if element.select_one('.ak-aside'):
            aside = element.select_one('.ak-aside').text.strip()
        if element.select_one('.ak-text'):
            text = element.select_one('.ak-text').text.strip()
        effects.append({
            "title": title,
            "text": aside + text
        })
        
    spell_details_effect_content = html_content.find('div', class_='ak-spell-details-effects')
    ak_main_content_elements = spell_details_effect_content.select('.ak-main-content')
    text = ""
    aside = ""
    effects = []
    for element in ak_main_content_elements:
        title = element.select_one('.ak-title').text.strip()
        if element.select_one('.ak-aside'):
            aside = element.select_one('.ak-aside').text.strip()
        if element.select_one('.ak-text'):
            text = element.select_one('.ak-text').text.strip()
        effects.append({
            "title": title,
            "text": aside + text
        })
    spell_details_critical_content = html_content.find('div', class_='ak-spell-details-critical')
    ak_main_content_elements = spell_details_critical_content.select('.ak-main-content')
    text = ""
    aside = ""
    critical = []
    for element in ak_main_content_elements:
        title = element.select_one('.ak-title').text.strip()
        if element.select_one('.ak-aside'):
            aside = element.select_one('.ak-aside').text.strip()
        if element.select_one('.ak-text'):
            text = element.select_one('.ak-text').text.strip()
        critical.append({
            "title": title,
            "text": aside + text
        })
    spell_details_other_content = html_content.find('div', class_='ak-spell-details-other')
    ak_main_content_elements = spell_details_other_content.select('.ak-main-content')
    text = ""
    aside = ""
    other = []
    for element in ak_main_content_elements:
        title = element.select_one('.ak-title').text.strip()
        if element.select_one('.ak-aside'):
            aside = element.select_one('.ak-aside').text.strip()
        if element.select_one('.ak-text'):
            text = element.select_one('.ak-text').text.strip()
        other.append({
            "title": title,
            "text": aside + text
        })
    return {
        "name" : spell_name,
        "range" : copy_range_ap_element.text.strip().split('/')[0].strip(),
        "ap": copy_range_ap_element.text.strip().split('/')[1].strip(),
        "description": spell_description_content.text.strip(),
        "level": level.text.strip(),
        "effects": effects,
        "critical": critical,
        "other": other
    }


def print_selected_spells(spell_list):
    spell_count_per_class = {}
    spell_details_list = []

    for spell_data in spell_list:
        class_name = spell_data["class_name"]
        spells = spell_data["spells"]

        for spell in spells:
            if any(
                effect["text"] == "Yes" and effect["title"] == "Modifiable range"
                for effect in spell["details"]["other"]
            ) and any(
                effect["text"] == "No" and effect["title"] == "Line of sight"
                for effect in spell["details"]["other"]
            ):
                # Append spell details to the list
                spell_details_list.append({
                    "class_name": class_name,
                    "spell_name": spell['details']['name'],
                    "description": spell['details']['description'],
                    "range": spell['details']['range'],
                    "level": spell['details']['level'],
                    "link": spell['spell_link']
                })

                # Update spell count for the class
                spell_count_per_class[class_name] = spell_count_per_class.get(class_name, 0) + 1

    # Sort classes by count in descending order
    sorted_classes = sorted(spell_count_per_class.items(), key=lambda x: x[1])

    for class_name, count in sorted_classes:
        print("---")
        print("---")
        print("---")
        for spell_details in spell_details_list:
            if spell_details["class_name"] == class_name:
                print(f"Class: {spell_details['class_name']}")
                print("Spell Details:")
                print(f"Name: {spell_details['spell_name']}")
                print(f"Description: {spell_details['description']}")
                print(f"Range: {spell_details['range']}")
                print(f"Level: {spell_details['level']}")
                print(f"Link: {spell_details['link']}")
                print("---")


    print("\nNumber of Spells Meeting Conditions per Class (Sorted by Count):")
    for class_name, count in sorted_classes:
        print(f"{class_name}: {count} spells")

# %%
html_content = get_html('https://www.dofus.com/en/mmorpg/encyclopedia/classes', ".ak-content-sections")
character_links = extract_links_from_html(html_content)
data_list = []
for character_link in character_links:
    character_data = {'character_link': character_link, 'spells': []}
    html_content_character = get_html("https://www.dofus.com" + character_link, ".ak-spell-list-row")
    spell_links = extract_links_from_html(html_content_character)
    for spell_link in spell_links:
        html_content_spell = get_html("https://www.dofus.com" + spell_link, "main")
        if html_content_spell:
            # Assuming you want to store the spell link and corresponding HTML content
            spell_data = {'spell_link': "https://www.dofus.com/" + spell_link, 'html_content': html_content_spell}
            character_data['spells'].append(spell_data)
    data_list.append(character_data)

# %%
data_list_copy = copy.copy(data_list)
# Convert HTML content to strings outside the loop
for character_data in data_list_copy:
    character_data["character_link"] =  character_data["character_link"].replace("https://www.dofus.comhttps://www.dofus.com", "https://www.dofus.com")
    
    character_data['class_name'] = character_data["character_link"].split('-')[1].strip()
    for spell_data in character_data['spells']:
            html_content_str = str(spell_data['html_content'])
            spell_data['spell_link'] = spell_data['spell_link'].replace("https://www.dofus.comhttps://www.dofus.com", "https://www.dofus.com")
            spell_data['html_content'] = html_content_str
            spell_data['details'] = extract_spell_info( BeautifulSoup(spell_data['html_content'], 'html.parser'))
    # Sort spells by level
    character_data['spells'] = sorted(character_data['spells'], key=lambda x: int(x['details']['level']))
    # Save the copied data to a JSON file
    with open(character_data['class_name'] + '.json', 'w', encoding='utf-8') as json_file:
        json.dump(character_data, json_file, indent=2)
# Sort the entire data_list_copy by class_name
data_list_copy_sorted = sorted(data_list_copy, key=lambda x: x['class_name'])
# Save the copied and sorted data to a single JSON file
with open('dofus_spells.json', 'w', encoding='utf-8') as json_file:
    json.dump(data_list_copy_sorted, json_file, indent=2)

# %%
# Specify the path to your JSON file
json_file_path = 'dofus_spells.json'

# Load data from the JSON file
with open(json_file_path, 'r', encoding='utf-8') as json_file:
    dofus_spells_data = json.load(json_file)
    
print_selected_spells(dofus_spells_data)
# Out:
# ---
# ---
# ---
# Class: sadida
# Spell Details:
# Name: Tear
# Description: Inflicts Water damage.
#
# On one of the caster's Trees: transforms it into a Leafy Tree.
#
# On an Infected enemy: inflicts Water damage on all Infected enemies.
# Range: 1 - 4 Range
# Level: 10
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13528&level=42112&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: feca
# Spell Details:
# Name: Barricade
# Description: Makes the targeted ally Invulnerable in Close Combat.
# For 1 turn, if they receive ranged damage, increases their MP (stackable 3 times).
#
# The MP increase is not applied if the target is under the effects of the Bastion spell.
#
# On a free cell: summons a static shield that makes adjacent allies in its glyph-aura Invulnerable in Close Combat.
# This shield is destroyed on the caster's next turn.
# Range: 4 Range
# Level: 10
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=12979&level=41036&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: feca
# Spell Details:
# Name: Bastion
# Description: Makes the targeted ally Invulnerable at Range.
# For 1 turn, if they receive close-combat damage, increases their Power (stackable 3 times).
#
# The Power increase is not applied if the target is under the effects of the Barricade spell.
#
# On a free cell: summons a static shield that makes adjacent allies in its glyph-aura Invulnerable at Range.
# This shield is destroyed on the caster's next turn.
# Range: 4 Range
# Level: 25
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=12995&level=41084&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: pandawa
# Spell Details:
# Name: Stabilisation
# Description: Applies the Rooted state on the target and increases MP Parry.
#
# Requires the Sober state.
# Range: 2 Range
# Level: 35
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=12789&level=40666&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: pandawa
# Spell Details:
# Name: Spirit Bond
# Description: Summons a biddable Pandawasta that removes Dodge, Power and Lock from opponents.
# It can also increase its characteristics during combat or carry the caster in the Sober state if the caster attacks it in close combat.
#
# The Pandawasta reduces immediate allied damage by 50%.
#
# If the caster's Pandawasta is still alive when the spell is recast, the old one is killed and replaced by a new one.
#
# Requires the Drunk state.
# Range: 1 - 4 Range
# Level: 85
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=12799&level=40696&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: cra
# Spell Details:
# Name: Piercing Shot
# Description: Inflicts Air damage in an area of effect.
# The spell's damage is increased for each entity hit after each casting.
#
# Damage does not decrease with distance.
# Range: 1 - 6 Range
# Level: 60
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13080&level=41242&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: cra
# Spell Details:
# Name: Raining Arrows
# Description: Inflicts Air damage in an area of effect.
# The area of effect extends around the caster's beacons, and the effects are applied only once per casting.
#
# Does not affect the caster.
# Damage does not decrease with distance.
# Range: 6 Range
# Level: 95
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13059&level=41203&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: cra
# Spell Details:
# Name: Covering Fire
# Description: Inflicts Earth damage in an area of effect.
# The area of effect extends around the caster's beacons, and the effects are applied only once per casting.
#
# Does not affect the caster.
# Range: 3 - 8 Range
# Level: 115
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=14636&level=44469&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: enutrof
# Spell Details:
# Name: Shovel Kiss
# Description: Inflicts Fire damage.
# Range: 1 - 4 Range
# Level: 3
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13331&level=41697&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: enutrof
# Spell Details:
# Name: Acceleration
# Description: Increases the targeted ally's MP.
# Range: 8 Range
# Level: 10
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13342&level=41730&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: enutrof
# Spell Details:
# Name: Golden Age
# Description: Makes the targeted ally Unlockable.
# Increases its Power on the following turn.
# Range: 6 Range
# Level: 160
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13329&level=41691&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: huppermage
# Spell Details:
# Name: Manifestation
# Description: Triggers the targeted rune.
#
# If an enemy is on the cell:
# • Inflicts damage on enemies in the rune's element.
# • Increases the caster's characteristics based on the rune's element.
# • Applies the rune's elemental state.
#
# If the cell is or becomes free, summons an Elemental Manifestation, applying the effects of the movement:
# • Earth: repels entities from the centre in a 3-cell circle around the Manifestation.
# • Fire: switches the positions of the caster and the Manifestation.
# • Water: attracts entities towards the centre in a 3-cell circle around the Manifestation.
# • Air: teleports entities symmetrically in relation to the Manifestation in a 3-cell circle around it.
#
# The Manifestation is destroyed on the next turn.
# When it dies, the Manifestation applies its elemental state in a 3-cell circle around itself.
#
# Can generate elemental combinations.
# Range: 1 - 6 Range
# Level: 105
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13710&level=42523&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: huppermage
# Spell Details:
# Name: Tectonic Breach
# Description: Places an Earth rune, inflicts Earth damage, and applies the Earth state.
#
# Can generate elemental combinations.
# Range: 2 - 7 Range
# Level: 130
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13725&level=42538&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: huppermage
# Spell Details:
# Name: Elemental Trap
# Description: Places a single-cell trap that applies effects on enemies based on their elemental state in a 2-cell circle:
# • Earth: reduces the duration of effects.
# • Fire: reduces heals received.
# • Water: applies the Gravity state.
# • Air: applies the Unable to Lock state.
#
# The effects cannot be unbewitched.
# Consumes the elemental states of enemies hit.
# Range: 1 - 6 Range
# Level: 180
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13719&level=42532&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: masqueraider
# Spell Details:
# Name: Tortoruga
# Description: Applies a shield on the targeted ally.
# The shield is halved on summons.
# Range: 4 - 6 Range
# Level: 40
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13398&level=41805&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: masqueraider
# Spell Details:
# Name: Picada
# Description: Inflicts Air damage and removes AP.
# Range: 2 - 5 Range
# Level: 100
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13405&level=41816&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: masqueraider
# Spell Details:
# Name: Martelo
# Description: Inflicts Earth damage and removes MP in an area of effect.
# Range: 1 - 4 Range
# Level: 130
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13389&level=41796&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: masqueraider
# Spell Details:
# Name: Armadur
# Description: Increases the target's MP and Dodge.
# Range: 3 - 7 Range
# Level: 150
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13411&level=44593&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: forgelance
# Spell Details:
# Name: Jormun
# Description: Teleports the Lance to the first available cell between it and the caster and inflicts Water damage on enemies in a line up to the targeted cell.
#
# On the caster: recalls their Lance and inflicts Water damage on enemies in a 2-cell circle around it and the caster.
#
# The damage does not decrease with distance and is less if the target is the caster.
# The effects are applied only once per casting.
# Range: 7 Range
# Level: 75
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=23268&level=59444&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: forgelance
# Spell Details:
# Name: Eclipse
# Description: Applies the Eclipse state on the caster:
# • Disarms the caster.
# • Applies a shield on the caster and their allies in a 3-cell circle around the caster.
# • Reduces everyone's Range.
#
# On the targeted cell on the following turn:
# • If the cell is occupied by the caster, casts the Mani's Crescent spell.
# • Otherwise, casts the Sigel's Disc spell.
#
# The Range removal cannot be unbewitched.
# Range: 8 Range
# Level: 90
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=23834&level=60731&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: forgelance
# Spell Details:
# Name: Lightning-Javelin
# Description: Summons the Lance and inflicts Water damage on enemies in a line up to the targeted cell.
# If the targeted cell is occupied by an enemy, also rebounds on the nearest enemy that is not in the area of effect in a 2-cell circle (maximum 3 times).
# Range: 2 - 5 Range
# Level: 100
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=23392&level=59799&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: forgelance
# Spell Details:
# Name: Elding
# Description: Summons the Lance, attracts targets towards the centre and inflicts Water damage on enemies in an area of effect.
# Does not affect the caster.
# Range: 1 - 6 Range
# Level: 175
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=23396&level=59803&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: forgelance
# Spell Details:
# Name: Renown
# Description: Attracts the target.
# If the target is an ally, heals the target as well. If not, heals the caster.
# If the caster is Disarmed, attracts the target towards their Lance.
#
# On the caster's Lance: recalls their Lance.
# Range: 6 Range
# Level: 180
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=23319&level=59689&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: xelor
# Spell Details:
# Name: Xelor's Sandglass
# Description: Inflicts Fire damage and removes AP from enemies.
#
# On a target in the Telefrag state: inflicts Fire damage on and removes AP from enemies in a 2-cell circle.
#
# Consumes the target's Telefrag state.
# Range: 1 - 6 Range
# Level: 25
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13261&level=41581&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: xelor
# Spell Details:
# Name: Flight
# Description: Increases the targeted ally's Dodge.
# Teleports the target back to its previous position on the following turn.
#
# The effects cannot be unbewitched.
#
# Can generate a Telefrag.
# Range: 2 Range
# Level: 70
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13251&level=41553&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: xelor
# Spell Details:
# Name: Desynchronisation
# Description: Places a single-cell trap that teleports entities symmetrically in relation to the trap in a 2-cell circle.
#
# Can generate a Telefrag.
# Range: 1 - 4 Range
# Level: 90
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13296&level=41643&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: xelor
# Spell Details:
# Name: Spontaneous Return
# Description: Teleports the target to its previous position.
#
# Can generate a Telefrag.
# Range: 2 Range
# Level: 105
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13282&level=41629&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: xelor
# Spell Details:
# Name: Temporal Instability
# Description: Places a start-of-turn glyph that teleports targets to their previous positions.
# Makes entities present in the glyph Unlockable.
#
# Triggers the glyph if the caster generates a Telefrag.
#
# Can generate a Telefrag.
# Range: 7 Range
# Level: 155
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13301&level=41648&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: rogue
# Spell Details:
# Name: Detonator
# Description: Adds 1 Combo to one of the caster's Bombs and makes it explode without line of sight.
# Gives 1 AP back to the caster before the explosion.
# Range: 1 - 4 Range
# Level: 1
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13432&level=41886&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: rogue
# Spell Details:
# Name: Magnet
# Description: Adds 1 Combo once per Bomb per turn in an area of effect. Does not affect the centre cell.
# Attracts the caster's Bombs in the area of effect towards the target. The Combo is only applied if the Bombs are effectively moved.
# May be used on the Megabomb or the Walking Bomb.
#
# Attracts other entities one cell only.
# Does not affect the caster.
# Range: 3 Range
# Level: 10
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13437&level=41901&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: rogue
# Spell Details:
# Name: Dirty Trick
# Description: Adds 1 Combo to one of the caster's Bombs, switches positions with it and applies the Gravity to it.
# The effects are only applied if the position switch can occur.
# May be used on the Megabomb.
#
# On an ally: only switches places with the target.
# Range: 1 - 4 Range
# Level: 20
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13439&level=41907&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: rogue
# Spell Details:
# Name: Kaboom
# Description: Applies the Kaboom state to allies in an area of effect.
#
# On caster's Bombs: adds 1 Combo.
# Range: 3 Range
# Level: 90
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13450&level=41938&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: rogue
# Spell Details:
# Name: Strategy
# Description: Teleports one of the caster's Bombs to its previous position and applies a shield to it.
#
# The shield is only applied if the teleportation can occur.
# May be used on the Megabomb or the Walking Bomb.
# Range: 1 - 6 Range
# Level: 160
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13476&level=42012&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: rogue
# Spell Details:
# Name: Magnetic Trap
# Description: Places a single-cell trap that attracts the targets, adds 1 Combo to the caster's Bombs, and causes them to explode in a 3-cell circle.
# Range: 1 - 8 Range
# Level: 190
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=13484&level=42023&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: sram
# Spell Details:
# Name: Arsenic
# Description: Applies a start-of-turn Air poison on the target.
# Range: 1 - 4 Range
# Level: 3
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=12907&level=40898&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: sram
# Spell Details:
# Name: Tricky Trap
# Description: Places a trap that inflicts Fire damage on enemies and attracts entities towards its centre in an area of effect.
# Range: 1 - 4 Range
# Level: 15
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=12906&level=40895&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: sram
# Spell Details:
# Name: Miry Trap
# Description: Places a trap that inflicts Water damage.
# Heals allies by up to 50% of damage inflicted on the entity that triggers it in a 2-cell circle around itself.
# Range: 1 - 4 Range
# Level: 20
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=12916&level=40925&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: sram
# Spell Details:
# Name: Malevolent Trap
# Description: Places a trap that inflicts Earth damage.
# The spell damage is increased for each enemy in a 2-cell circle around the trap.
# Range: 1 - 4 Range
# Level: 25
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=12948&level=40985&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: sram
# Spell Details:
# Name: Repelling Trap
# Description: Places a trap that pushes entities and inflicts Air damage on enemies in an area of effect.
# Range: 1 - 5 Range
# Level: 30
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=12914&level=40919&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: sram
# Spell Details:
# Name: Paralysing Trap
# Description: Places a trap that removes MP from enemies in an area of effect.
# Range: 1 - 4 Range
# Level: 35
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=12910&level=40907&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: sram
# Spell Details:
# Name: Drift Trap
# Description: Places a trap that inflicts Fire damage on enemies and pushes entities away from the centre in an area of effect.
# Range: 1 - 4 Range
# Level: 65
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=12942&level=40979&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: sram
# Spell Details:
# Name: Sickrat Trap
# Description: Places a single-cell trap that attracts entities towards its centre and inflicts Water damage on enemies in a 3-cell cross.
# Range: 1 - 5 Range
# Level: 70
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=12931&level=40968&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: sram
# Spell Details:
# Name: Lethal Trap
# Description: Inflicts Earth damage.
# The damage is greater on entities with less than 25% of their health points.
# Range: 1 - 7 Range
# Level: 80
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=12921&level=40940&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: sram
# Spell Details:
# Name: Frightful Trap
# Description: Places a single-cell trap that inflicts Earth damage on enemies and repels entities in a 3-cell cross.
# Range: 1 - 7 Range
# Level: 140
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=12920&level=40937&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: sram
# Spell Details:
# Name: Mass Grave
# Description: Places a single-cell trap that applies the Gravity state in a 2-cell circle.
# Range: 1 - 6 Range
# Level: 145
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=14314&level=43798&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: sram
# Spell Details:
# Name: Insidious Trap
# Description: Places a trap that applies an end-of-turn Air poison on enemies, inflicts Air damage on them, and attracts entities towards the centre in an area of effect.
# Range: 1 - 6 Range
# Level: 175
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=12918&level=40931&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: sram
# Spell Details:
# Name: Fragmentation Trap
# Description: Places a single-cell trap that inflicts Fire damage in a 3-cell circle.
# The damage is greater depending on the distance from the trap.
# Does not affect the ally that triggers the trap.
# Range: 1 - 6 Range
# Level: 180
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=12941&level=40978&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: sram
# Spell Details:
# Name: Plot
# Description: Increases the targeted ally's Dodge and Damage.
#
# On an enemy: removes Dodge and damage.
# Range: 6 Range
# Level: 185
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=14741&level=44739&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: sram
# Spell Details:
# Name: Calamity
# Description: Places a single-cell trap that inflicts Water damage and removes Dodge from enemies in a 1-cell square.
# Range: 1 - 6 Range
# Level: 190
# Link: https://www.dofus.comhttps://www.dofus.com//en/mmorpg/encyclopedia/spells/details?id=12950&level=40987&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
#
# Number of Spells Meeting Conditions per Class (Sorted by Count):
# sadida: 1 spells
# feca: 2 spells
# pandawa: 2 spells
# cra: 3 spells
# enutrof: 3 spells
# huppermage: 3 spells
# masqueraider: 4 spells
# forgelance: 5 spells
# xelor: 5 spells
# rogue: 6 spells
# sram: 15 spells
