# %%
from selenium import webdriver
import httpx
from bs4 import BeautifulSoup
import json
import copy

# %%
def get_html(url, element_selector):
    # Initialize the webdriver using WebDriverManager
    driver = webdriver.Chrome()
    driver.get(url)
    
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    # Find the element based on the provided selector
    selected_element = soup.select_one(element_selector)
    return selected_element

    
def extract_links_from_html(html_content):
    # Find all anchor tags (a) and extract their href attributes
    links = [a.get('href') for a in html_content.find_all('a')]

    # Filter out None values and remove duplicates
    unique_links = list(filter(None, set(links)))
    return unique_links


def extract_spell_info(html_content):
    spell_name_element = html_content.find('h2', class_='ak-spell-name')
    # Create a copy of the h2 element
    copy_spell_name_element = BeautifulSoup(str(spell_name_element), 'html.parser')
    # Remove undesired tags from the copy
    for tag in copy_spell_name_element.find_all(['div', 'span']):
        tag.decompose()
    # Extract spell name directly from the copied element
    spell_name = copy_spell_name_element.text.strip()
    # Extract range and AP content
    range_ap_content = html_content.find('span', class_='ak-spell-po-pa')
    # Create a copy of the h2 element
    copy_range_ap_element = BeautifulSoup(str(range_ap_content), 'html.parser')
    # Extract Minimum Required Level
    level =  html_content.select_one('.ak-spell-details-level .ak-selected')
    spell_description_content = html_content.find('span', class_='ak-spell-description')
    spell_details_effect_content = html_content.find('div', class_='ak-spell-details-effects')
    ak_main_content_elements = spell_details_effect_content.select('.ak-main-content')
    text = ""
    aside = ""
    effects = []
    for element in ak_main_content_elements:
        title = element.select_one('.ak-title').text.strip()
        if element.select_one('.ak-aside'):
            aside = element.select_one('.ak-aside').text.strip()
        if element.select_one('.ak-text'):
            text = element.select_one('.ak-text').text.strip()
        effects.append({
            "title": title,
            "text": aside + text
        })
        
    spell_details_effect_content = html_content.find('div', class_='ak-spell-details-effects')
    ak_main_content_elements = spell_details_effect_content.select('.ak-main-content')
    text = ""
    aside = ""
    effects = []
    for element in ak_main_content_elements:
        title = element.select_one('.ak-title').text.strip()
        if element.select_one('.ak-aside'):
            aside = element.select_one('.ak-aside').text.strip()
        if element.select_one('.ak-text'):
            text = element.select_one('.ak-text').text.strip()
        effects.append({
            "title": title,
            "text": aside + text
        })
    spell_details_critical_content = html_content.find('div', class_='ak-spell-details-critical')
    ak_main_content_elements = spell_details_critical_content.select('.ak-main-content')
    text = ""
    aside = ""
    critical = []
    for element in ak_main_content_elements:
        title = element.select_one('.ak-title').text.strip()
        if element.select_one('.ak-aside'):
            aside = element.select_one('.ak-aside').text.strip()
        if element.select_one('.ak-text'):
            text = element.select_one('.ak-text').text.strip()
        critical.append({
            "title": title,
            "text": aside + text
        })
    spell_details_other_content = html_content.find('div', class_='ak-spell-details-other')
    ak_main_content_elements = spell_details_other_content.select('.ak-main-content')
    text = ""
    aside = ""
    other = []
    for element in ak_main_content_elements:
        title = element.select_one('.ak-title').text.strip()
        if element.select_one('.ak-aside'):
            aside = element.select_one('.ak-aside').text.strip()
        if element.select_one('.ak-text'):
            text = element.select_one('.ak-text').text.strip()
        other.append({
            "title": title,
            "text": aside + text
        })
    return {
        "name" : spell_name,
        "range" : copy_range_ap_element.text.strip().split('/')[0].strip(),
        "ap": copy_range_ap_element.text.strip().split('/')[1].strip(),
        "description": spell_description_content.text.strip(),
        "level": level.text.strip(),
        "effects": effects,
        "critical": critical,
        "other": other
    }


def print_selected_spells(spell_list):
    spell_count_per_class = {}
    spell_details_list = []

    for spell_data in spell_list:
        class_name = spell_data["class_name"]
        spells = spell_data["spells"]

        for spell in spells:
            if any(
                effect["text"] == "Yes" and effect["title"] == "Modifiable range"
                for effect in spell["details"]["other"]
            ) and any(
                effect["text"] == "No" and effect["title"] == "Line of sight"
                for effect in spell["details"]["other"]
            ):
                # Append spell details to the list
                spell_details_list.append({
                    "class_name": class_name,
                    "spell_name": spell['details']['name'],
                    "description": spell['details']['description'],
                    "range": spell['details']['range'],
                    "level": spell['details']['level'],
                    "link": spell['spell_link']
                })

                # Update spell count for the class
                spell_count_per_class[class_name] = spell_count_per_class.get(class_name, 0) + 1

    # Sort classes by count in descending order
    sorted_classes = sorted(spell_count_per_class.items(), key=lambda x: x[1])

    for class_name, count in sorted_classes:
        print("---")
        print("---")
        print("---")
        for spell_details in spell_details_list:
            if spell_details["class_name"] == class_name:
                print(f"Class: {spell_details['class_name']}")
                print("Spell Details:")
                print(f"Name: {spell_details['spell_name']}")
                print(f"Description: {spell_details['description']}")
                print(f"Range: {spell_details['range']}")
                print(f"Level: {spell_details['level']}")
                print(f"Link: {spell_details['link']}")
                print("---")


    print("\nNumber of Spells Meeting Conditions per Class (Sorted by Count):")
    for class_name, count in sorted_classes:
        print(f"{class_name}: {count} spells")

# %%
#html_content = get_html('https://www.dofus.com/en/mmorpg/encyclopedia/classes', ".ak-content-sections")
#character_links = extract_links_from_html(html_content)
#data_list = []
#for character_link in character_links:
#    character_data = {'character_link': character_link, 'spells': []}
#    html_content_character = get_html("https://www.dofus.com" + character_link, ".ak-spell-list-row")
#    spell_links = extract_links_from_html(html_content_character)
#    for spell_link in spell_links:
#        html_content_spell = get_html("https://www.dofus.com" + spell_link, "main")
#        if html_content_spell:
#            # Assuming you want to store the spell link and corresponding HTML content
#            spell_data = {'spell_link': https://www.dofus.com/ spell_link, 'html_content': html_content_spell}
#            character_data['spells'].append(spell_data)
#    data_list.append(character_data)
# Save the data to a JSON file
#with open('output_data.json', 'w') as json_file:
#    json.dump(data_list, json_file, indent=2)
#print("Data saved to output_data.json")
# Convert HTML content to strings outside the loop
#for character_data in data_list_copy:
#    character_data["character_link"] =  "https://www.dofus.com" + character_data["character_link"]
#    character_data['class_name'] = character_data["character_link"].split('-')[1].strip()
#    for spell_data in character_data['spells']:
#            html_content_str = str(spell_data['html_content'])
#            spell_data['spell_link'] =  "https://www.dofus.com" + spell_data['spell_link']
#            spell_data['html_content'] = html_content_str
#            spell_data['details'] = extract_spell_info( BeautifulSoup(spell_data['html_content'], 'html.parser'))
#    # Sort spells by level
#    character_data['spells'] = sorted(character_data['spells'], key=lambda x: int(x['details']['level']))
#    # Save the copied data to a JSON file
#    with open(character_data['class_name'] + '.json', 'w', encoding='utf-8') as json_file:
#        json.dump(character_data, json_file, indent=2)
# Sort the entire data_list_copy by class_name
#data_list_copy_sorted = sorted(data_list_copy, key=lambda x: x['class_name'])
# Save the copied and sorted data to a single JSON file
#with open('dofus_spells.json', 'w', encoding='utf-8') as json_file:
#    json.dump(data_list_copy_sorted, json_file, indent=2)

# %%
# Specify the path to your JSON file
json_file_path = 'dofus_spells.json'

# Load data from the JSON file
with open(json_file_path, 'r', encoding='utf-8') as json_file:
    dofus_spells_data = json.load(json_file)
    
print_selected_spells(dofus_spells_data)
# Out:
# ---
# ---
# ---
# Class: Sram
# Spell Details:
# Name: Invisibility
# Description: Makes the targeted ally invisible and increases their MP.
# Range: 4 Range
# Level: 1
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12913&level=40916&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Sram
# Spell Details:
# Name: Fear
# Description: Pushes the target to the targeted cell.
# Range: 2 - 6 Range
# Level: 60
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12908&level=40901&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: Cra
# Spell Details:
# Name: Distant Shots
# Description: Increases allies' Range in an area of effect.
# Range: 0 Range
# Level: 10
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13058&level=41200&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Cra
# Spell Details:
# Name: Absolute Acuteness
# Description: Deactivates line of sight on all the caster's spells.
#
# The effects cannot be unbewitched.
# Range: 0 Range
# Level: 120
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13073&level=41235&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Cra
# Spell Details:
# Name: Sentinel
# Description: Immobilises the caster to:
# • Increase their spell damage.
# • Give their Cra spells infinite range.
# • Reveal all invisible entities in their line of sight.
# Range: 0 Range
# Level: 200
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13087&level=41249&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: Eniripsa
# Spell Details:
# Name: War Cry
# Description: Inflicts Earth damage on enemies in an area of effect around the caster.
# Also repels Painted enemies in the area of effect.
#
# Damage does not decrease with distance.
# Range: 0 Range
# Level: 50
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=25863&level=65821&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Eniripsa
# Spell Details:
# Name: Lifting Word
# Description: Switches places with the targeted ally.
# Range: 1 - 4 Range
# Level: 75
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13184&level=41431&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Eniripsa
# Spell Details:
# Name: Sobs
# Description: Inflicts Water damage.
# Heals allies for up to 100% of damage inflicted on the targeted enemy in a 2-cell circle around the enemy.
# Range: 1 - 5 Range
# Level: 110
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=25872&level=65830&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Eniripsa
# Spell Details:
# Name: Defensive Word
# Description: Moves the caster closer to the targeted enemies and steals health from them in the Water element in a line up to the targeted cell.
# Range: 1 - 5 Range
# Level: 145
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=25876&level=65834&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Eniripsa
# Spell Details:
# Name: Fountain of Youth
# Description: Heals allies and places an end-of-turn glyph that heals allies in an area of effect.
# Makes the caster Unlockable as long as they are inside the glyph.
# Range: 2 Range
# Level: 185
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=25874&level=65832&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: Foggernaut
# Spell Details:
# Name: Scaphander
# Description: Increases the MP, Damage and Pushback Damage of allies in an area of effect.
# Range: 0 Range
# Level: 15
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13819&level=42724&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Foggernaut
# Spell Details:
# Name: Piston
# Description: Repels the targeted ally.
# The push is greater on Turrets.
# Range: 1 - 1 Range
# Level: 90
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=14308&level=43753&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Foggernaut
# Spell Details:
# Name: Assistance
# Description: Teleports the allied target to the first cell available between the caster and it.
# If the targeted ally is one of the caster's Turrets, also heals it.
# Range: 1 - 7 Range
# Level: 120
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13862&level=42842&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Foggernaut
# Spell Details:
# Name: Periscope
# Description: Activates the caster's tactical Turrets' special spells on the target.
#
# Inflicts Water damage on enemies.
# Range: 5 Range
# Level: 160
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13870&level=42850&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Foggernaut
# Spell Details:
# Name: Short-Circuit
# Description: Kills one of the caster's Turrets to inflict Air damage in an area of effect.
# Sets the destroyed Turret's cooldown period to 1 turn.
# Range: 1 - 63 Range
# Level: 170
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13872&level=42852&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Foggernaut
# Spell Details:
# Name: Recursiveness
# Description: Repels the target.
#
# If the target ends its movement next to an allied Turret, the Turret teleports it symmetrically and reapplies the spell's effects on it.
#
# If the caster casts the spell on themself, they also move with the Turrets if they are adjacent to one of them.
# Range: 1 Range
# Level: 200
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13876&level=42856&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: Eliotrope
# Spell Details:
# Name: Audacious
# Description: Moves the caster closer to the target and inflicts Water damage on enemies.
#
# Cast through a portal: inflicts Water damage only.
# Range: 1 - 3 Range
# Level: 1
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=14593&level=44396&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Eliotrope
# Spell Details:
# Name: Bullying
# Description: Inflicts Air damage on enemies in an area of effect and pushes targets back from the centre of the area of effect.
#
# The pushback only affects the caster if cast through a portal.
# Range: 4 Range
# Level: 40
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=14592&level=44393&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Eliotrope
# Spell Details:
# Name: Sinecure
# Description: Inflicts Air damage and reduces Pushback Resistance.
# Range: 1 - 5 Range
# Level: 80
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=14610&level=44432&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Eliotrope
# Spell Details:
# Name: Mutual Assistance
# Description: On everyone for 2 turns, if an entity (excluding the caster) uses a portal:
# • Increases the caster's AP.
# • Heals the caster and their allies in a 2-cell circle around the caster.
# Range: 0 Range
# Level: 90
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=14596&level=44405&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Eliotrope
# Spell Details:
# Name: Interruption
# Description: Deactivates all allied portals.
# Range: 0 Range
# Level: 120
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=14607&level=44429&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Eliotrope
# Spell Details:
# Name: Exodus
# Description: Teleports the caster symmetrically in relation to the target.
# Range: 1 - 1 Range
# Level: 165
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=14616&level=44438&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Eliotrope
# Spell Details:
# Name: Conflagration
# Description: Heals the targeted ally and reduces the final damage inflicted by enemies in an area of effect.
# Range: 5 Range
# Level: 180
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=14622&level=44444&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Eliotrope
# Spell Details:
# Name: Virus
# Description: Inflicts Fire damage on enemies in an area of effect.
# Heals allies in the area of effect by 50% of the damage inflicted on enemies.
# Does not affect the caster.
# Range: 4 Range
# Level: 185
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=14619&level=44441&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: Rogue
# Spell Details:
# Name: Boombot
# Description: Summons a controllable robot capable of pushing, attracting or trigger the caster's Bombs.
# The robot dies at the end of its turn.
# Range: 1 - 1 Range
# Level: 35
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13429&level=41879&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Rogue
# Spell Details:
# Name: Roguery
# Description: Applies a shield on all the caster's Bombs.
# The shield is also applied on their Megabomb and Walking Bomb.
#
# Creates several images of the caster to trick their opponents, and allows the caster to teleport. The images disappear if they suffer damage.
# Ends the caster's current turn.
#
# The effects cannot be unbewitched.
# Range: 1 - 4 Range
# Level: 50
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13431&level=41883&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Rogue
# Spell Details:
# Name: Last Breath
# Description: Reduces the caster's maximum Vitality to temporarily add 3 Combos to their Bombs.
#
# The effects cannot be unbewitched.
# Range: 0 Range
# Level: 80
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13446&level=41928&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Rogue
# Spell Details:
# Name: Deception
# Description: Inflicts Water damage and removes AP in the area of effect.
# Does not affect the caster.
#
# On the caster's Bombs: teleports them symmetrically in relation to the centre of the area of effect.
# May be used on the Megabomb or the Walking Bomb.
# Range: 1 Range
# Level: 85
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13443&level=41919&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Rogue
# Spell Details:
# Name: Crossing
# Description: Adds 1 Combo once per Bomb per turn in an area of effect. Does not affect the centre cell.
# Attracts the caster's Bombs in the area of effect towards the targeted cell. The Combo is only applied if the Bombs are effectively moved.
# May be used on the Megabomb or the Walking Bomb.
# Range: 6 Range
# Level: 120
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13480&level=42016&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Rogue
# Spell Details:
# Name: Walking Bomb
# Description: Summons a controllable Bomb that can obtain an element and Combos by targeting an elemental Bomb.
# It self-destructs to place a Bomb in the corresponding element at the end of its turn and adds up to 7 Combos to the targeted Bomb.
# This Bomb enters the Pacifist state until the caster's next turn starts.
#
# It is destroyed after 2 turns if it has not obtained an element.
# Range: 1 - 1 Range
# Level: 130
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13487&level=42026&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Rogue
# Spell Details:
# Name: Megabomb
# Description: Summons a controllable Megabomb that inflicts Neutral damage.
# Its damage increases each time it devours a Bomb. It loses 1 MP per bomb devoured.
# When it dies, it explodes and adds 1 Combo to the caster's Bombs and causes them to explode in a 2-cell area of effect around it.
#
# The Megabomb is vulnerable to bomb walls.
# Range: 1 - 1 Range
# Level: 145
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13490&level=42029&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Rogue
# Spell Details:
# Name: Shot Pellets
# Description: Steals HP in the Fire element in an area of effect.
# The health steal is reduced by half on allies.
# Range: 2 - 4 Range
# Level: 185
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=14411&level=44007&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: Enutrof
# Spell Details:
# Name: Living Bag
# Description: Summons a biddable Living Bag that suffers damage on behalf of its allies located in its summoning zone.
# The Living Bag disappears 3 turns after it was summoned.
#
# When attacked by an ally, the ally is healed.
# Range: 1 - 3 Range
# Level: 1
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13328&level=41688&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Enutrof
# Spell Details:
# Name: Pandora's Box
# Description: Heals all allies but increases the MP of all enemies.
# Range: 0 Range
# Level: 15
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13334&level=41706&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Enutrof
# Spell Details:
# Name: Living Shovel
# Description: Summons a biddable Living Shovel that pushes its targets.
#
# When attacked by an ally, the ally is healed.
# Range: 1 - 2 Range
# Level: 35
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13344&level=41736&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Enutrof
# Spell Details:
# Name: Greed
# Description: Removes Power from everyone and increases the caster's Power for each entity hit.
# Range: 0 Range
# Level: 40
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13339&level=41721&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Enutrof
# Spell Details:
# Name: Vivacity
# Description: Heals the targeted ally and switches places with the target.
# Range: 1 - 1 Range
# Level: 65
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13364&level=41770&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Enutrof
# Spell Details:
# Name: Pull Out
# Description: Immobilises targets and applies the Gravity state on everyone. Does not affect the caster.
# Immobilises the caster on the following turn.
#
# The effects cannot be unbewitched.
# Range: 0 Range
# Level: 75
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13349&level=41751&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Enutrof
# Spell Details:
# Name: Toolbox
# Description: Increases the targeted ally's AP and MP but makes the ally Pacifist.
# If the ally is not a summons, also makes all the ally's summons Pacifist.
# Range: 1 - 5 Range
# Level: 125
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13357&level=41763&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Enutrof
# Spell Details:
# Name: Living Spade
# Description: Summons a biddable Living Spade that steals HP in the Air element.
# The Spade increases its Dodge and that of the Enutrof and their summons when it does damage.
#
# When it is attacked by an ally, the ally is healed.
# Range: 1 - 7 Range
# Level: 145
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13361&level=41767&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Enutrof
# Spell Details:
# Name: Miserliness
# Description: Removes unparryable MP but increases AP in an area of effect. Does not affect the caster.
# Range: 0 Range
# Level: 150
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13362&level=41768&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: Huppermage
# Spell Details:
# Name: Ether
# Description: Places an Air rune, inflicts Air damage, and applies the Air state.
#
# Can generate elemental combinations.
# Range: 1 - 4 Range
# Level: 1
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13669&level=42413&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Huppermage
# Spell Details:
# Name: Runification
# Description: Triggers all of the caster's runes that are occupied by an enemy:
# • Inflicts damage on enemies in the rune's element.
# • Increases the caster's characteristics based on the rune's element for each enemy hit.
# • Applies the rune's elemental state.
#
# Can generate elemental combinations.
# Range: 0 Range
# Level: 1
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13670&level=42414&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Huppermage
# Spell Details:
# Name: Polarity
# Description: Applies movement effects based on the targeted enemy's elemental state:
# • Earth: repels the target.
# • Fire: switches places with the target.
# • Water: attracts the target.
# • Air: teleports the caster symmetrically in relation to the target.
#
# Consumes the elemental state.
# Range: 1 - 4 Range
# Level: 25
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13696&level=42493&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Huppermage
# Spell Details:
# Name: Glacier
# Description: Places Water runes, steals HP in the Water element, and applies the Water state in an area of effect.
#
# Can generate elemental combinations.
# Range: 0 Range
# Level: 35
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13676&level=42420&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Huppermage
# Spell Details:
# Name: Journey
# Description: Teleports the caster to the targeted cell and inflicts damage in the elemental state of enemies in a line up to the targeted cell.
# Range: 5 - 5 Range
# Level: 40
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13683&level=42427&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Huppermage
# Spell Details:
# Name: Deflagration
# Description: Reduces the duration of the target's effects, places a Fire rune, inflicts Fire damage on enemies, and applies the Fire state and the Deflagration state.
#
# The unbewitchment cannot be applied if the target is already in the Deflagration state.
#
# Can generate elemental combinations.
# Range: 3 Range
# Level: 50
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13681&level=42425&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Huppermage
# Spell Details:
# Name: Imprint
# Description: Places a rune under all enemies affected by an elemental state.
# Range: 0 Range
# Level: 85
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13697&level=42496&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Huppermage
# Spell Details:
# Name: Quadramental Current
# Description: Applies effects on the targeted enemy based on their elemental state:
# • Earth: removes MP.
# • Fire: removes AP.
# • Water: erodes the target.
# • Air: removes Range.
# Each effect can be stacked one time.
# Range: 1 - 6 Range
# Level: 135
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13716&level=42529&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Huppermage
# Spell Details:
# Name: Runic Repulsion
# Description: Repels targets in an area of effect and repels them again for each of the caster's runes.
# The pushback for each rune consumed is reduced.
#
# Consumes all of the caster's runes.
# Range: 0 Range
# Level: 150
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13728&level=42541&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: Xelor
# Spell Details:
# Name: Teleportation
# Description: Teleports the caster symmetrically relative to the target.
#
# Sets the spell's cooldown period to 0 when a Telefrag is generated or consumed by the caster.
#
# Can generate a Telefrag.
# Range: 1 - 3 Range
# Level: 1
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13249&level=41547&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Xelor
# Spell Details:
# Name: Rhol Bak
# Description: Teleports everyone to their previous positions.
#
# Can generate a Telefrag.
# Range: 0 Range
# Level: 45
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13262&level=41584&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Xelor
# Spell Details:
# Name: Temporal Paradox
# Description: On the caster's Accomplice or Xelor's Dial:
# • Applies the Unmovable state.
# • Teleports entities symmetrically in relation to them in a 4-cell circle around them.
# • Sets the cooldown period of the caster's Accomplice and Xelor's Dial spells to 1 turn.
# • At the start of the Accomplice's or Dial's turn, teleports these entities again.
#
# Teleportation does not affect a Synchro and the caster.
#
# The effects cannot be unbewitched.
#
# Can generate a Telefrag.
# Range: 0 Range
# Level: 55
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13250&level=41550&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Xelor
# Spell Details:
# Name: Synchro
# Description: Summons a static Synchro that dies and inflicts Air damage on enemies in a 3-cell circle when it enters the Telefrag state. Damage does not decrease with distance.
#
# It is healed and its final damage inflicted increases with each Telefrag generated by the caster.
# This effect can only be triggered 1 time per turn and 1 time per spell.
#
# The Synchro is immune to the Mummification and Embalming spells and cannot be activated with the Rewind spell.
#
# There can only be one Synchro per team. If the Synchro is still alive when summoned again, the old one is killed to make room for the new one.
# Range: 1 - 2 Range
# Level: 60
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13247&level=41541&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Xelor
# Spell Details:
# Name: Mummification
# Description: Increases the caster's MP and their AP Parry and applies the Telefrag state on everyone.
# Range: 0 Range
# Level: 85
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13260&level=41578&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Xelor
# Spell Details:
# Name: Temporal Distortion
# Description: Inflicts Air damage on enemies and teleports targets to their previous positions in a area of effect.
# Does not affect the caster.
#
# Can generate a Telefrag.
# Range: 0 Range
# Level: 135
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13289&level=41636&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Xelor
# Spell Details:
# Name: Pendulum
# Description: Teleports the caster symmetrically in relation to the target, inflicts Air damage on enemies in a 2-cell circle around the caster, and teleports the caster to their previous position.
#
# Can generate a Telefrag.
# Range: 1 - 4 Range
# Level: 160
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13294&level=41641&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Xelor
# Spell Details:
# Name: Time Rift
# Description: Switches places with the caster's Accomplice or Xelor's Dial.
# At the end of the caster's turn, teleports the Accomplice or Dial to its previous position.
#
# Prevents the Telefrag state from being applied on the Synchro for the current turn.
#
# The effects cannot be unbewitched.
#
# Can generate a Telefrag.
# Range: 0 Range
# Level: 165
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13295&level=41642&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Xelor
# Spell Details:
# Name: Twenty-Fifth Hour
# Description: Sets the cooldown period of the caster's following spells to 0:
# • Teleportation
# • Rewind or Reflect
# • Xelor's Dial
# • Conservation
# • Rhol Bak or Temporal Instability
# • Temporal Paradox or Time Rift
# • Counter or Temporal Oop Shield
# • Premonition
# • Mummification
#
# Increases the number of casts per turn of the caster's following spells by 1:
# • Spontaneous Return
# • Accomplice
# • Flight
# • Embalming
# • Desynchronisation
# Range: 0 Range
# Level: 170
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=14650&level=44504&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Xelor
# Spell Details:
# Name: Premonition
# Description: Places a rune that teleports the caster or switches their place with the entity on the targeted cell at the start of their next turn.
#
# Can generate a Telefrag.
# Range: 5 Range
# Level: 180
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13293&level=41640&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: Ecaflip
# Spell Details:
# Name: Perception
# Description: Heals the targeted ally for each enemy in the area of effect and reveals invisible entities in an area of effect.
# Range: 6 Range
# Level: 20
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12852&level=40794&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ecaflip
# Spell Details:
# Name: All or Nothing
# Description: On enemies in an area of effect: immediately inflicts Water damage in an area of effect and heals the targets on the following turn.
#
# On allies in an area of effect: immediately heals the targets in an area of effect and inflicts Water damage on the following turn.
#
# The caster is always affected first, whether or not they are in the area of effect.
# Range: 2 Range
# Level: 25
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12858&level=40812&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ecaflip
# Spell Details:
# Name: Roulette
# Description: Summons a Roulette that provides a random bonus to everyone at the start of its turn.
#
# There can only be one Roulette per team. If the Roulette is still alive when summoned again, the old one is killed to make room for the new one.
# Range: 1 - 3 Range
# Level: 30
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12840&level=40761&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ecaflip
# Spell Details:
# Name: Feline Spirit
# Description: Inflicts Earth damage on enemies and teleports the caster symmetrically in relation to the target.
# Range: 1 - 1 Range
# Level: 50
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12847&level=40779&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ecaflip
# Spell Details:
# Name: Clover
# Description: Transfers the Critical odds from the caster's Ecaflip's Coin to the target for 2 turns.
#
# Removes the effects of Ecaflip's Coin from the caster.
# Range: 3 Range
# Level: 55
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12843&level=40767&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ecaflip
# Spell Details:
# Name: Smell
# Description: Immediately removes unparryable AP to increase MP in an area of effect.
# Removes unparryable MP to increase AP on the following turn.
#
# The AP removal does not affect the caster.
# Range: 1 Range
# Level: 60
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12854&level=40800&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ecaflip
# Spell Details:
# Name: Playful Claw
# Description: Inflicts Water damage in an area of effect.
# Range: 1 - 3 Range
# Level: 70
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12849&level=40785&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ecaflip
# Spell Details:
# Name: Leap
# Description: Teleports the caster onto the targeted cell and increases allies' Dodge in an area of effect.
# Range: 1 - 1 Range
# Level: 115
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12865&level=40832&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ecaflip
# Spell Details:
# Name: Yowling
# Description: Inflicts Fire damage on enemies and heals allies in an area of effect.
# Range: 1 - 4 Range
# Level: 120
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12872&level=40839&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ecaflip
# Spell Details:
# Name: Roar
# Description: Increases the caster's Power for each enemy in the area of effect and reveals invisible entities in an area of effect.
# Range: 0 Range
# Level: 130
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12867&level=40834&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ecaflip
# Spell Details:
# Name: Spell Strike
# Description: Summons a Spell Strike that gives a random bonus to its attacker when attacked.
# Gives a random bonus to its summoner when summoned.
#
# There can only be one Spell Strike per team. If the Spell Strike is still alive when summoned again, the old one is killed to make room for the new one.
# Range: 1 - 3 Range
# Level: 140
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12871&level=40838&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: Iop
# Spell Details:
# Name: Jump
# Description: Teleports the caster onto the targeted cell and increases damage received by enemies in an area of effect.
# Range: 1 - 5 Range
# Level: 1
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13107&level=41277&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Iop
# Spell Details:
# Name: Divine Sword
# Description: Inflicts Air damage on enemies and increases allies' damage in an area of effect.
# Range: 0 Range
# Level: 3
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13110&level=41286&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Iop
# Spell Details:
# Name: Blow
# Description: Pushes targets from the centre of the area of effect.
# Range: 2 - 4 Range
# Level: 15
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13116&level=41304&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Iop
# Spell Details:
# Name: Friction
# Description: Attracts the target and applies the Friction state on the target:
# • If the target is an enemy, moves the target closer to the target's enemy attackers.
# • If the target is an ally, attracts the target's enemy attackers to the target.
# Range: 4 Range
# Level: 35
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13113&level=41295&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Iop
# Spell Details:
# Name: Duel
# Description: Makes the caster and the targeted enemy Invulnerable at long range, applies the Gravity state on them, and immobilises them.
# The caster's Gravity state is conserved on the following turn.
#
# The effects cannot be unbewitched.
# Range: 1 - 1 Range
# Level: 40
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13109&level=41283&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Iop
# Spell Details:
# Name: Sword of Fate
# Description: Inflicts Fire damage.
# Spell damage is increased for one turn on the second turn after casting.
# Range: 1 - 2 Range
# Level: 80
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13111&level=41289&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Iop
# Spell Details:
# Name: Fracture
# Description: Erodes the targets and inflicts Air damage in a line up to the targeted cell.
# Range: 1 - 4 Range
# Level: 95
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13139&level=41349&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Iop
# Spell Details:
# Name: Violence
# Description: Increases the caster's Pushback Damage for each enemy in the area of effect and repels targets in an area of effect.
# Range: 0 Range
# Level: 125
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13137&level=41347&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Iop
# Spell Details:
# Name: Virtue
# Description: Applies a shield on the allies in an area of effect but reduces the caster's Power.
# Range: 0 Range
# Level: 130
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13142&level=41352&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Iop
# Spell Details:
# Name: Sword of Judgement
# Description: Applies a shield to the caster, inflicts Water damage and applies the Condemned state to the target:
# • Inflicts greater delayed Water damage to the target.
#
# The shield is greater and the delay is reset on a Condemned target.
#
# On the caster: applies a shield.
# Range: 4 Range
# Level: 135
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13117&level=41307&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Iop
# Spell Details:
# Name: Grip
# Description: Makes the targeted enemy Invulnerable and immobilises them.
#
# The effects cannot be unbewitched.
# Range: 1 - 1 Range
# Level: 150
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13141&level=41351&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: Osamodas
# Spell Details:
# Name: Flaming Crow
# Description: Inflicts Fire damage on enemies or heals allies.
# The spell's damage, minimum range and maximum range are increased after each casting for the current turn.
#
# Gives a Wyrmlicharge (requires a target).
# Range: 1 - 5 Range
# Level: 25
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=14022&level=43111&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Osamodas
# Spell Details:
# Name: Animal Blessing
# Description: Gives 3 summoning charges in the current family of charges.
#
# If the caster is Uncharged: gives 3 summoning charges in the family of the last charge gained.
# Range: 0 Range
# Level: 60
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=14028&level=43117&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Osamodas
# Spell Details:
# Name: Whip
# Description: Attracts the caster's Osamodas summons towards the centre of the area of effect.
# If the cell is occupied, teleports the Osamodas summons symmetrically in relation to the target.
# Range: 1 - 5 Range
# Level: 85
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12557&level=40268&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Osamodas
# Spell Details:
# Name: Call to Order
# Description: Kills an allied summons.
#
# On one of the caster's Tofus, Gobballs, Toads or Wyrmlings: grants one summoning charge based on the summons's family and colour, and returns AP to the caster based on the summons's colour before killing the summons.
# The cooldown period of the associated summoning spell is not applied.
# Range: 1 - 5 Range
# Level: 90
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12564&level=40287&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Osamodas
# Spell Details:
# Name: Beastly Balance
# Description: Changes the summoning charge family based on the current family:
# • Tofu -> Gobball -> Toad -> Wyrmling -> Tofu.
# • The spell's AP cost is reimbursed on the first casting.
#
# If the caster is Uncharged: gives 1 summoning charge in the family of the last charge gained.
# Range: 0 Range
# Level: 125
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=14025&level=43114&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Osamodas
# Spell Details:
# Name: Takeoff
# Description: Switches places with the target.
# • If it is an enemy: inflicts Air damage on it.
# • If it is one of the caster's Osamodas summons: inflicts Air damage on enemies in a 2-cell circle around the caster and the summons.
#
# The AoE damage is only applied once per casting, and only if the position switch can occur.
#
# Gives a Tofucharge (requires a target).
# Gives a second Tofucharge if the target is one of the caster's Osamodas summons.
# Range: 1 - 3 Range
# Level: 145
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12550&level=40251&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Osamodas
# Spell Details:
# Name: Gobball Fleece
# Description: Applies shield points per enemy hit on allies and inflicts Earth damage on enemies in an area of effect.
#
# Gives a Gobbacharge if an enemy is hit.
# Gives a Gobbacharge if an ally (excluding the caster) is hit.
# Range: 2 Range
# Level: 150
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=14020&level=43109&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Osamodas
# Spell Details:
# Name: Dragon Heart
# Description: Heals allies and inflicts Fire damage on enemies in a 2-cell circle around the caster's Wyrmlings.
# Healing is reduced by half on the caster.
#
# Gives a Wyrmlicharge.
# Range: 0 Range
# Level: 160
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12612&level=40366&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Osamodas
# Spell Details:
# Name: Batra
# Description: Inflicts Water damage on enemies in a 2-cell circle around the caster and their Toads.
# Applies a start-of-turn Water poison on enemies if they are in the area of effect of the caster and a Toad, or of two Toads.
# The effects are applied only once per casting.
#
# Gives a Toacharge.
# Range: 0 Range
# Level: 175
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=14016&level=43105&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Osamodas
# Spell Details:
# Name: Relay
# Description: Switches the positions of the targeted ally and the nearest of the caster's summons to that ally if they are 5 cells apart or closer.
# If that ally is a summons, also increases its AP.
#
# The effects are only applied if the position switch can occur.
# The AP bonus is transmitted when the Noformo transforms.
# Range: 1 - 5 Range
# Level: 180
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12617&level=40371&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Osamodas
# Spell Details:
# Name: Nature Preserve
# Description: Applies effects on all of the caster's Osamodas summons based on the last summoning charge gained:
# • Tofucharge: increases MP.
# • Gobbacharge: applies a shield.
# • Toacharge: increases Power.
# • Wyrmlicharge: heals.
#
# The effects cannot be unbewitched.
# Range: 0 Range
# Level: 190
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=18656&level=51254&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: Masqueraider
# Spell Details:
# Name: Coward Mask
# Description: Applies the Coward Mask on the caster:
# • Applies the Cowardly state on the caster.
# • Increases the MP and Dodge of the caster and their allies (excluding Masqueraiders) in an area of effect.
# Range: 0 Range
# Level: 1
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13387&level=41794&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Masqueraider
# Spell Details:
# Name: Intrepid Mask
# Description: Applies the Intrepid Mask on the caster:
# • Applies the Intrepid state on the caster.
# • Increases the AP of the caster and their allies (excluding Masqueraiders) in a 1-cell cross.
# • Attracts entities towards the centre in an area of effect.
# Range: 0 Range
# Level: 1
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13386&level=41793&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Masqueraider
# Spell Details:
# Name: Catalepsy
# Description: Steals HP in the Earth element and removes Dodge in an area of effect.
# Does not affect the caster.
# Range: 0 Range
# Level: 3
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13420&level=41865&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Masqueraider
# Spell Details:
# Name: Psychopath Mask
# Description: Applies the Psychopath Mask on the caster:
# • Applies the Psychopathic state on the caster.
# • Increases the close-combat damage and Lock of the caster and their allies (excluding Masqueraiders) in an area of effect.
# Range: 0 Range
# Level: 6
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13388&level=41795&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Masqueraider
# Spell Details:
# Name: Plastron
# Description: Applies a shield around allies in an area of effect.
# The shield is halved on summons.
# Range: 0 Range
# Level: 25
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13397&level=41804&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Masqueraider
# Spell Details:
# Name: Ponteira
# Description: Inflicts Water damage and removes damage.
# Range: 1 - 6 Range
# Level: 60
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13422&level=41867&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Masqueraider
# Spell Details:
# Name: Grimace
# Description: Summons a biddable Grimacing Mask that locks enemies and shares its damage with its summoner as long as it is alive.
# When an enemy is locked by the Mask, the mask and its summoner gain shield.
#
# The Grimacing Mask also applies effects depending on the mask worn by its summoner:
# • Intrepid: attracts entities in a 3-cell cross around it.
# • Coward: increases its MP.
# • Psychopath: repels adjacent entities.
#
# When it dies, the spell's cooldown period is set to 3 turns.
# If the Grimacing Mask is still alive when the spell is recast, it is teleported to the targeted cell.
# Range: 1 - 1 Range
# Level: 75
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13424&level=41869&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Masqueraider
# Spell Details:
# Name: Poltroon Mask
# Description: Applies the Poltroon Mask on the caster:
# • Applies the Cowardly state on the caster.
# • Increases the ranged damage and Range of the caster and their allies (excluding Masqueraiders) in an area of effect.
# Range: 0 Range
# Level: 95
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13406&level=41851&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Masqueraider
# Spell Details:
# Name: Tireless Mask
# Description: Applies the Tireless Mask on the caster:
# • Applies the Intrepid state on the caster.
# • Applies a shield on the caster.
# • Increases the AP of the caster and their allies (excluding Masqueraiders) in an area of effect.
# Range: 0 Range
# Level: 105
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13409&level=41854&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Masqueraider
# Spell Details:
# Name: Hysterical Mask
# Description: Applies the Hysterical Mask on the caster:
# • Applies the Psychopathic state on the caster.
# • Increases the Pushback Damage of the caster and their allies (excluding Masqueraiders) in an area of effect.
# • Repels targets in an area of effect.
# Range: 0 Range
# Level: 115
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13414&level=41859&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Masqueraider
# Spell Details:
# Name: Masquerade
# Description: Inflicts Neutral damage on the caster and the target:
# • The damage inflicted on the target depends on the caster's remaining health.
# • The damage inflicted on the caster depends on how much health they are missing.
# • The effects are inverted if the caster is below 50% health.
#
# On the caster: switches places with their Grimacing Mask.
# Range: 1 - 1 Range
# Level: 155
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13404&level=41811&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Masqueraider
# Spell Details:
# Name: Diffraction
# Description: Applies shield on everyone depending on distance from the caster:
# • 0 to 5 cells, 450% of level as shield.
# • 6 to 11 cells, 250% of level as shield.
# • 12 or more cells, 50% of level as shield.
# The shield is halved on summons.
# Range: 0 Range
# Level: 185
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13385&level=41792&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: Ouginak
# Spell Details:
# Name: Prey
# Description: Applies the Prey state on the targeted enemy.
# Entities who attack the target are healed by some of the damage inflicted.
#
# If the Prey dies, sets the spell's cooldown period to 0.
#
# There can only be one Prey per team.
# If the spell is cast on another enemy, its effects are removed from the previous target.
# Range: 1 - 6 Range
# Level: 1
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13748&level=42580&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ouginak
# Spell Details:
# Name: Watchdog
# Description: Inflicts Earth damage on enemies and reduces damage suffered by the caster.
#
# The effects cannot be unbewitched.
#
# Increases the caster's Rage (requires a target).
# Range: 1 - 1 Range
# Level: 1
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13756&level=42600&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ouginak
# Spell Details:
# Name: Tibia
# Description: Inflicts Water damage on enemies and repels the targets in an area of effect around the caster.
#
# Increases the caster's Rage.
# Range: 0 Range
# Level: 25
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13763&level=42619&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ouginak
# Spell Details:
# Name: R-Canine
# Description: Increases the caster's Power.
#
# Requires and reduces the caster's Rage.
# Range: 0 Range
# Level: 30
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13771&level=42643&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ouginak
# Spell Details:
# Name: Appeasement
# Description: Heals the caster.
# Requires and reduces the caster's Rage.
#
# If the caster is in their Animal Form: removes the effects of Animal Form.
# Range: 0 Range
# Level: 60
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13769&level=42637&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ouginak
# Spell Details:
# Name: Sniff
# Description: Teleports the caster to the first available cell adjacent to the Prey.
#
# If the Prey is in the area of effect: teleports the caster to the targeted cell.
#
# Requires and reduces the caster's Rage.
# Range: 1 - 63 Range
# Level: 85
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13749&level=42583&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ouginak
# Spell Details:
# Name: Venison
# Description: Applies the Prey state on the targeted enemy and increases its damage suffered.
#
# There can only be one Prey per team.
# If the spell is cast on another enemy, its effects are removed from the previous target.
# Range: 1 - 5 Range
# Level: 95
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13786&level=42688&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ouginak
# Spell Details:
# Name: Humerus
# Description: Teleports the caster symmetrically in relation to the target and inflicts Earth damage on enemies.
#
# Increases the caster's Rage (requires a target).
# Range: 1 - 1 Range
# Level: 135
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13794&level=42696&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ouginak
# Spell Details:
# Name: Snuggletooth
# Description: Heals the caster.
#
# Requires and reduces the caster's Rage.
# Range: 0 Range
# Level: 140
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13797&level=42699&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ouginak
# Spell Details:
# Name: Affection
# Description: Heals the caster and the targeted ally and switches places with them.
# Requires and reduces the caster's Rage.
#
# If the caster is in their Animal Form: removes the effects of Animal Form.
# Range: 1 - 4 Range
# Level: 170
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13791&level=42693&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ouginak
# Spell Details:
# Name: Gnaw
# Description: Increases the caster's Power, Pushback Damage and Lock and applies the Gnaw state on them:
# • Increases these same characteristics if the caster suffers damage.
# Range: 0 Range
# Level: 185
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=13803&level=42705&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Ouginak
# Spell Details:
# Name: New Moon
# Description: Reduces the duration of effects on the caster and transforms them into a Beast.
#
# Cannot be used in Animal Form.
# Range: 0 Range
# Level: 200
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=14321&level=43816&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ...
# Range: 0 Range
# Level: 145
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12729&level=40553&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Sacrier
# Spell Details:
# Name: Carnage
# Description: Sacrifices some of the caster's health to inflict Air damage in an area of effect.
#
# The damage does not affect the caster.
# Range: 1 - 1 Range
# Level: 170
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12752&level=40606&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Sacrier
# Spell Details:
# Name: Penitence
# Description: Switches places with the targeted ally and applies the Penitence state on the target:
# • If it is an ally: switches places with the caster upon taking damage.
# • If it is an enemy: switches places with the caster upon inflicting damage on the caster.
#
# The effects cannot be unbewitched.
# Range: 1 - 6 Range
# Level: 175
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12764&level=40618&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Sacrier
# Spell Details:
# Name: Gash
# Description: Sacrifices some of the caster's health to inflict Earth damage.
# Range: 1 - 1 Range
# Level: 180
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12751&level=40605&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Sacrier
# Spell Details:
# Name: Blood Pact
# Description: Increases the caster's Vitality but temporarily sacrifices some of their health.
# Range: 0 Range
# Level: 190
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=12762&level=40616&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# ---
# ---
# ---
# Class: Forgelance
# Spell Details:
# Name: Epilogue
# Description: Recalls the Lance and returns 1 AP to the caster.
#
# On the caster: recalls only their Lance.
# Range: 4 Range
# Level: 1
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23801&level=60674&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Slingshot
# Description: Inflicts Earth damage on enemies in an area of effect and summons the Lance.
# Damage does not decrease with distance.
# Range: 1 - 3 Range
# Level: 1
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23719&level=60542&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Fire Lance
# Description: Summons the Lance, moves the caster closer to their Lance, and inflicts Fire damage on enemies in a line up to the targeted cell and in a 2-cell semi-circle.
#
# Applies a Surtr Spark on the enemies hit.
# Range: 2 - 4 Range
# Level: 3
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23263&level=59439&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Collapse
# Description: Inflicts Earth damage on enemies and attracts the targets up to the centre in an area of effect.
# Does not affect the caster.
# Damage does not decrease with distance.
#
# If the caster is Disarmed: the spell's range is infinite, and the effects can only be applied around the caster's Lance.
# Range: 2 Range
# Level: 15
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23736&level=60565&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Phalanx
# Description: Applies a shield around allies and increases their Pushback Resistance in an area of effect.
# The shield is greater on the caster.
#
# If the caster is Disarmed: the spell's range is infinite, and the effects can only be applied around the caster's Lance.
# Range: 0 Range
# Level: 25
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23330&level=59713&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Balestra
# Description: Teleports the caster to the first available cell between them and the target, teleports the caster symmetrically in relation to the target and inflicts Water damage on enemies in a line up to the targeted cell.
#
# The caster is only teleported symmetrically if they are teleported adjacent to the target.
# Range: 1 - 3 Range
# Level: 40
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23434&level=59848&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Kyrja
# Description: Teleports the caster to the targeted cell, steals health from enemies in the caster's best attack element, and reduces those enemies' final damage inflicted in a line up to the targeted cell.
# Range: 2 - 3 Range
# Level: 50
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23823&level=60717&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Maelstrom
# Description: Summons or teleports the Lance to the targeted cell and inflicts Fire damage on enemies in an area of effect.
# If the cell is occupied, recalls the Lance.
# Damage does not decrease with distance.
#
# Removes Surtr Sparks from all enemies and applies one to those in the area of effect.
#
# The effects are only applied if the summoning, teleportation or recall is done.
# Range: 1 Range
# Level: 55
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23747&level=60581&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Iron Prelude
# Description: Reduces the duration of effects on enemies and increases allies' Power in an area of effect.
#
# If the caster is Disarmed: the spell's range is infinite, and the effects can only be applied around the caster's Lance.
# Range: 2 Range
# Level: 60
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23841&level=60743&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Cyclone Lancer
# Description: Summons the Lance, inflicts Air damage on enemies and repels targets in a line up to the targeted cell.
# Range: 2 - 4 Range
# Level: 65
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23729&level=60556&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Chivalry
# Description: Heals allies and increases their MP in an area of effect.
# Healing is greater on the caster.
#
# If the caster is Disarmed, also recalls their Lance.
# Range: 0 Range
# Level: 70
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23826&level=60720&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Middle Earth
# Description: Increases the caster's Power for each enemy in the area of effect and inflicts Earth damage in an area of effect.
#
# If the caster is Disarmed: the spell's range is infinite, and the effects can only be applied around the caster's Lance.
#
# The damage does not affect the caster.
# Range: 0 Range
# Level: 85
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23738&level=60567&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Seismic Pike
# Description: Inflicts Earth damage on enemies in an area of effect.
# If the cell is or becomes free, summons the Lance.
# Damage does not decrease with distance.
# Range: 1 - 1 Range
# Level: 95
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23720&level=60543&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Parry
# Description: Recalls the Lance and applies the Parry state on the caster. At the end of their turn:
# • Recalls their Lance again.
# • Applies the Unmovable state on the caster.
# • Reduces damage from the next attack on them in close combat.
# • If they suffer close-combat damage, inflicts damage in their best attack element on their attacker and repels the attacker.
# The effects are removed after the caster suffers close-combat damage.
#
# Interception and damage-sharing effects are incompatible with the spell.
# The effects cannot be unbewitched.
# Range: 0 Range
# Level: 105
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23386&level=59789&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Disengaging
# Description: Inflicts Air damage on enemies and pushes targets back from the centre in an area of effect.
# Does not affect the caster.
#
# If the caster is Disarmed: the spell's range is infinite, the effects can only be applied around the caster's Lance, and the Lance is recalled.
# Range: 0 Range
# Level: 110
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23743&level=60572&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Hot Iron
# Description: Inflicts Fire damage on enemies in a 2-cell square without diagonals.
#
# If the caster is Disarmed: the spell's range is infinite, and the effects can only be applied around the caster's Lance.
#
# The Surtr Sparks' damage is increased for each enemy hit until the next time Sparks are removed.
# Range: 1 - 2 Range
# Level: 115
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23756&level=60592&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Gallantry
# Description: Moves the caster away from the target, attracts the target and heals the caster and the targeted ally.
# If the target is the Lance, also recalls the Lance.
# Range: 1 - 1 Range
# Level: 120
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23314&level=59682&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Brass Rain
# Description: Inflicts Air damage and reduces Pushback Resistance in an area of effect.
#
# If the caster is Disarmed: the spell's range is infinite, and the effects can only be applied around the caster's Lance.
#
# Does not affect the caster.
# Range: 1 Range
# Level: 125
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=24219&level=61562&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Spicy Mill
# Description: Inflicts Fire damage on enemies and attracts the targets up to the centre of the area of effect.
# Does not affect the caster.
#
# On the caster or on their Lance: the effects are applied in a 3-cell cross.
# If the caster is Disarmed: the spell's range is infinite, and the effects can only be applied around the caster's Lance.
#
# Applies a Surtr Spark on the enemies hit.
# Range: 2 Range
# Level: 130
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23755&level=60591&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Oriflamme
# Description: Summons or teleports the Lance to the targeted cell, applies a shield on allies and increases their Critical Resistance in an area of effect.
# Range: 1 - 2 Range
# Level: 135
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23828&level=60723&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Octave
# Description: Increases the caster's Range and inflicts Water damage on enemies.
#
# If the caster is Disarmed: moves the caster away from the target.
# Range: 1 - 1 Range
# Level: 140
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23391&level=59798&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Upheaval
# Description: Teleports targets symmetrically in relation to the caster and inflicts Earth damage on enemies in an area of effect.
# Damage does not decrease with distance.
# Range: 1 - 1 Range
# Level: 145
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23731&level=60558&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Windmill
# Description: Teleports targets symmetrically in relation to the centre and inflicts Air damage on enemies in an area of effect.
#
# If the caster is Disarmed: the spell's range is infinite, and the effects can only be applied around the caster's Lance.
#
# Does not affect the caster.
# Range: 1 Range
# Level: 150
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23742&level=60571&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Lunge
# Description: Teleports the caster to the targeted cell and inflicts Fire damage on enemies in an area of effect.
#
# Applies a Surtr Spark on the enemies hit.
# Range: 1 - 1 Range
# Level: 155
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23753&level=60588&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Vajra
# Description: Teleports the caster to the targeted cell, steals Dodge and steals health from enemies in the caster's best attack element in an area of effect.
# Range: 2 - 4 Range
# Level: 160
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23829&level=60724&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Ydra
# Description: Switches places with the Lance, inflicts Earth damage on enemies in an area of effect around the caster and their Lance, and recalls the Lance.
# The effects are only applied if the position switch can occur.
#
# On the caster: inflicts Earth damage on enemies in an area of effect around the caster and their Lance, and recalls the Lance.
#
# Damage does not decrease with distance.
# Range: 5 Range
# Level: 165
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23723&level=60546&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Twilight
# Description: Erodes enemies and reduces their Range in an area of effect.
#
# If the caster is Disarmed: the spell's range is infinite, and the effects can only be applied around the caster's Lance.
# Range: 2 Range
# Level: 170
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23842&level=60744&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Muspel
# Description: Summons or teleports the Lance to the targeted cell and inflicts Fire damage on enemies in an area of effect.
#
# Damage does not decrease with distance and is only inflicted if the summoning or teleportation is done.
#
# Applies 2 Surtr Sparks on the enemies hit.
# Range: 1 - 4 Range
# Level: 185
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23750&level=60584&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Valkyr's Embrace
# Description: Reduces damage suffered by the targeted ally and applies the Valkyr's Embrace state on the ally:
# • Erodes the target's enemy attackers.
#
# The effects cannot be unbewitched.
# Range: 6 Range
# Level: 190
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23838&level=60737&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
# Class: Forgelance
# Spell Details:
# Name: Holmgang
# Description: Applies the Unmovable and Holmgang states on the caster:
# • Reduces the ranged damage they suffer.
# • Places a glyph-aura that attracts enemies that cross it and inflicts damage on them in the caster's best attack element (one time per enemy per turn).
# • Ends the caster's current turn.
# Range: 0 Range
# Level: 200
# Link: https://www.dofus.com/en/mmorpg/encyclopedia/spells/details?id=23846&level=60748&selector=1&characterlevel=1&showlevel=0&startingspell=0
# ---
#
# Number of Spells Meeting Conditions per Class (Sorted by Count):
# Sram: 2 spells
# Cra: 3 spells
# Eniripsa: 5 spells
# Foggernaut: 6 spells
# Eliotrope: 8 spells
# Rogue: 8 spells
# Enutrof: 9 spells
# Huppermage: 9 spells
# Xelor: 10 spells
# Ecaflip: 11 spells
# Iop: 11 spells
# Osamodas: 11 spells
# Masqueraider: 12 spells
# Ouginak: 12 spells
# Feca: 15 spells
# Pandawa: 15 spells
# Sadida: 16 spells
# Sacrier: 22 spells
# Forgelance: 30 spells
